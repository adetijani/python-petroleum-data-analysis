# %%
name= input("Enter your name:")
print("Hello",name,"Welcome!")
# Out:
# Enter your name: Adebowale
# Hello Adebowale Welcome!

# %%
a=("Hello World")
print(a)
# Out:
# Hello World

# %%
a="petroleum"
print(a)
# Out:
# petroleum

# %%
a="Petroluem"
b="fluid"
print(a,b)
# Out:
# Petroluem fluid

# %%
b="Petroleum"
c="interface"
print(a,b,c)
# Out:
# Data Petroleum interface

# %%
#take user input
name=input("Enter your name")
print("Hello", name, "welcome!")
print(name)
# Out:
# Enter your name Adebowale
# Hello Adebowale welcome!
# Adebowale

# %%
#taking two inputs at a time
x, y= input("enter two values:").split()
print("Number of boys:",x)
print("Number of girls:",y)
# Out:
# enter two values: 22 24
# Number of boys: 22
# Number of girls: 24

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width

print("Area =", area)
# Out:
# Enter length:  5
# Enter width:  7
# Area = 35.0
